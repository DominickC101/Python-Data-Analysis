# %% [markdown]
# #### While Loop Assignment

# %%
current_inventory = 686
monthly_sales = 84
month = 0

#Print current inventory after monthly sales until sales <= 0.
while current_inventory > 0:
    month += 1
    current_inventory -= monthly_sales
    print(f"At the end of month {month}, we have {current_inventory}")
# Out:
# At the end of month 1, we have 602
# At the end of month 2, we have 518
# At the end of month 3, we have 434
# At the end of month 4, we have 350
# At the end of month 5, we have 266
# At the end of month 6, we have 182
# At the end of month 7, we have 98
# At the end of month 8, we have 14
# At the end of month 9, we have -70
