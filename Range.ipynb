# %% [markdown]
# #### Range Assignment

# %%
even_numbers = list(range(2,12,2))
print(even_numbers)

odd_numbers = list(range(1, 11, 2))
print(odd_numbers)

seventh_customer = list(range(7, 100, 7))
print(seventh_customer)
# Out:
# [2, 4, 6, 8, 10]
# [1, 3, 5, 7, 9]
# [7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]
