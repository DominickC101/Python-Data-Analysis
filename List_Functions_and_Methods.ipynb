# %% [markdown]
# #### List Functions and Methods Assignments

# %%
customer_ids = ["C00001", "C00001", "C00001", "C00002", "C00003", "C00004", "C00004", "C00005", "C00006", "C00006", "C00007", "C00008", "C00008", "C00010", "C00010", "C00013", "C00014", "C00015", "C00016", "C00016", "C00017", "C00018", "C00018", "C00019", "C00020", "C00021", "C00022"]
subtotals = [15.98, 899.97, 799.97, 117.96, 5.99, 599.99, 24.99, 1799.94, 99.99, 254.95, 29.98, 99.99, 25.98, 649.98, 89.99, 119.99, 599.99, 649.98, 24.99, 99.99, 99.99, 5.99, 24.99, 999.96, 99.99, 399.97, 89.99]

#Calculate the average subtotal.
average_subtotal = round(sum(subtotals) / len(subtotals), 2)
print(average_subtotal)

#Count how many times 'C00010' made a transaction 
num_of_transactions = customer_ids.count('C00010')
print(num_of_transactions)

#Look up the subtotal of 'C00010' first transaction.
first_index = customer_ids.index('C00010')
first_transaction = subtotals[first_index]
print(first_transaction)

#Compare 'C00010' first transaction subtotal to the average subtotal
if average_subtotal > first_transaction:
    print('The average subtotal is greater than C00010 first transaction')
elif average_subtotal < first_transaction:
    print("C00010's first transaction is greater than average subtotal")
else:
    print("The average subtotal is equal to C00010's first transaction")

#Compare the average subtotal to 'C00010' average transaction
C00010_average = (first_transaction + subtotals[14]) / 2
if average_subtotal > C00010_average:
    print("The average subtotal is greater than C00010's average")
elif average_subtotal < C00010_average:
    print("The average subtotal is less than C00010's average")
else:
    print('The averages are the same')

#Print a sorted list of customer ids
print(sorted(customer_ids))
# Out:
# 323.39
# 2
# 649.98
# C00010's first transaction is greater than average subtotal
# The average subtotal is less than C00010's average
# ['C00001', 'C00001', 'C00001', 'C00002', 'C00003', 'C00004', 'C00004', 'C00005', 'C00006', 'C00006', 'C00007', 'C00008', 'C00008', 'C00010', 'C00010', 'C00013', 'C00014', 'C00015', 'C00016', 'C00016', 'C00017', 'C00018', 'C00018', 'C00019', 'C00020', 'C00021', 'C00022']
