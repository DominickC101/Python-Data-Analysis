# %% [markdown]
# #### Tuple Assignment

# %%
multi_order_customers = [[1799.94, 29.98, 99.99], [15.98, 119.99], [24.99, 24.99], [649.99, 99.99], [599.99, 399.97]]
transaction1, transaction2, transaction3 = multi_order_customers[0]
sales_tax = .08
C00001_total = round((sum(multi_order_customers[0]) * sales_tax) + sum(multi_order_customers[0]), 2)
print(C00001_total)
# Out:
# 2084.3
