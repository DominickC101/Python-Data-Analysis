# %% [markdown]
# #### Nested Loops Assignment

# %%
orders_c00001 = [1799.94, 29.98, 99.99]
orders_c00004 = [15.98, 119.99]
orders_c00006 = [24.99, 24.99]
orders_c00008 = [649.99, 99.99]
orders_c00010 = [599.99, 399.97]
multi_order_customers = [orders_c00001, orders_c00004, orders_c00006, orders_c00008, orders_c00010]

#apply a 10% discount to each transaction and return the discounted prices in the same format as the original.
discounted_prices = []
for customer in multi_order_customer:
    customer_discounts = []
    for transaction in customer:
        customer_discounts.append(round(transaction - (transaction * .1), 2))
    discounted_prices.append(customer_discounts)
print(discounted_prices)
# Out:
# [[1619.95, 26.98, 89.99], [14.38, 107.99], [22.49, 22.49], [584.99, 89.99], [539.99, 359.97]]
