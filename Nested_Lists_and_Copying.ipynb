# %% [markdown]
# #### Nested Lists and Copying Assignment

# %%
orders_c00001 = [1799.94, 29.98, 99.99]
orders_c00004 = [15.98, 119.99]
orders_c00006 = [24.99, 24.99]
orders_c00008 = [649.99, 99.99]
orders_c00010 = [599.99, 397.99]

#Combine all orders into a list.
orders = [c, orders_c00004, orders_c00006, orders_c00008, orders_c00010]
print(orders)

#Print the last 2 transactions from 'orders_c00001'.
print(orders[0][1:])

#Create a copy of the list and Change the transaction value for 'c00004' to 0.0 WITHOUT changing the original
order_copy = orders.copy()
order_copy[1] = [0.0, 0.0]
print(order_copy)
# Out:
# [[1799.94, 29.98, 99.99], [15.98, 119.99], [24.99, 24.99], [649.99, 99.99], [599.99, 397.99]]
# [29.98, 99.99]
# [[1799.94, 29.98, 99.99], [0.0, 0.0], [24.99, 24.99], [649.99, 99.99], [599.99, 397.99]]
