# %% [markdown]
# # Tax Printing Code Change
# ## * Create a tax variable and change it to a value of 2.
# ## * Create a total value equal to price + tax.
# ## * Print total

# %%
price = 5
tax = 2
total = price + tax
print(total)
# Out:
# 7
